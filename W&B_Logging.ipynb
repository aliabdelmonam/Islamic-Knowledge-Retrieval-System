# %%
# !pip install wandb

# %%
# !wandb login
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: aliabdelmonam37 to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
import wandb

run = wandb.init(
    entity="RAG-Hadith",   # your team name
    project="temp project",       # shared project — same for everyone
    name="this is temp push",  # descriptive run name
    config={
        # log everything you want to compare later
        "embedding_model":  "alwa embeddings",
        "chunk_size":       "chunk_size_alwa",
        "chunk_overlap":    "overlap_alwa",
        "retriever_type":   "retriever_type_alwa",
        "search_type":      "search_type_alwa",
        "search_kwargs":    "search_kwargs_alwa",
        "k":                "k_alwa",
        "llm_provider":     "llm-provider-alwa",
        "llm_model":        "llm-model-alwa" ,
        "temperature":      "temperature_alwa",
        "max_tokens":       "max_tokens_alwa",
        "prompt_template":  "prompt_template_alwa"
    }
)
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: aliabdelmonam37 to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.27.0
# Run data is saved locally in <code>/content/wandb/run-20260607_101432-9krkrvzj</code>
# Syncing run <strong><a href='https://wandb.ai/RAG-Hadith/temp%20project/runs/9krkrvzj' target="_blank">this is temp push</a></strong> to <a href='https://wandb.ai/RAG-Hadith/temp%20project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/RAG-Hadith/temp%20project' target="_blank">https://wandb.ai/RAG-Hadith/temp%20project</a>
# ...

# %%
wandb.log({
    "faithfulness":        0.87,
    "answer_relevancy":    0.91,
    "context_recall":      0.83,
    "context_precision":   0.79,
    "answer_correctness":  0.85,
})

# %%
wandb.finish()
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>answer_correctness</td><td>▁</td></tr><tr><td>answer_relevancy</td><td>▁</td></tr><tr><td>context_precision</td><td>▁</td></tr><tr><td>context_recall</td><td>▁</td></tr><tr><td>faithfulness</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>answer_correctness</td><td>0.85</td></tr><tr><td>answer_relevancy</td><td>0.91</td></tr><tr><td>context_precision</td><td>0.79</td></tr><tr><td>context_reca
# ...
